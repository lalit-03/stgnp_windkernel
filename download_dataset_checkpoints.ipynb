# %%
# %pip install gdown
# !gdown --no-check-certificate --folder "https://drive.google.com/drive/folders/1u2TazNL6dcaEUnAXrm4BiLdeLMXa9zoi"
# !gdown --no-check-certificate --folder "https://drive.google.com/drive/folders/1nESwyNrqOsYvUwvZBwAotck29kTCkn87"
# Out:
# Retrieving folder list
# /home/gnn/mambaforge/envs/stgnp/lib/python3.11/site-packages/urllib3/connectionpool.py:1095: InsecureRequestWarning: Unverified HTTPS request is being made to host 'drive.google.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Retrieving folder 10b9--rsQpxh8M8yOQsJXdRn-ujO6p0CF bjair
# /home/gnn/mambaforge/envs/stgnp/lib/python3.11/site-packages/urllib3/connectionpool.py:1095: InsecureRequestWarning: Unverified HTTPS request is being made to host 'drive.google.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Retrieving folder 19i2rf84w9xkP0UOmxJ_Ti6G8G3YDWwAa NP
# ...
